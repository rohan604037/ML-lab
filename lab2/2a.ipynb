# %% [markdown]
# <a href="https://colab.research.google.com/github/rohan604037/ML-lab/blob/main/lab2/lab2a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split

# load the iris dataset
iris = datasets.load_iris()

df = pd.DataFrame(iris.data)
label = pd.DataFrame(iris.target)

# Let us split 70% for training & 30% for testing
x_train, x_test, y_train, y_test = train_test_split(
    df, label, test_size=0.3, shuffle=True
)

# x -> df, y -> label
x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, test_size=0.3, shuffle=True
)

print("Total no. of samples in the dataset :", df.shape[0])
print("Total no. of labels in the dataset :", label.shape[0])

print("Total no. of samples in training set x_train :", x_train.shape[0])
print("Total no. of labels in training set y_train :", y_train.shape[0])

print("Total no. of samples in testing set x_test :", x_test.shape[0])
print("Total no. of labels in testing set y_test :", y_test.shape[0])

print("Total no. of samples in validation set x_val :", x_val.shape[0])
print("Total no. of labels in validation set y_val :", y_val.shape[0])

print("The 1st 3 samples of training set")
print(x_train.head(3))

print("The random 3 samples of training set")
print(x_train.sample(3))

print("The 1st 3 samples of testing set")
print(x_test.head(3))

print("The 3 samples of randomization")
print(x_test.sample(3))

print("The 1st 3 samples of validation set")
print(x_val.head(3))

print("The random 3 samples of validation")
print(x_val.sample(3))
# Out:
# Total no. of samples in the dataset : 150
# Total no. of labels in the dataset : 150
# Total no. of samples in training set x_train : 73
# Total no. of labels in training set y_train : 73
# Total no. of samples in testing set x_test : 45
# Total no. of labels in testing set y_test : 45
# Total no. of samples in validation set x_val : 32
# Total no. of labels in validation set y_val : 32
# The 1st 3 samples of training set
#       0    1    2    3
# 9   4.9  3.1  1.5  0.1
# 76  6.8  2.8  4.8  1.4
# 45  4.8  3.0  1.4  0.3
# The random 3 samples of training set
#       0    1    2    3
# 74  6.4  2.9  4.3  1.3
# 72  6.3  2.5  4.9  1.5
# 6   4.6  3.4  1.4  0.3
# The 1st 3 samples of testing set
#        0    1    2    3
# 44   5.1  3.8  1.9  0.4
# 118  7.7  2.6  6.9  2.3
# 52   6.9  3.1  4.9  1.5
# The 3 samples of randomization
#        0    1    2    3
# 39   5.1  3.4  1.5  0.2
# 115  6.4  3.2  5.3  2.3
# 2    4.7  3.2  1.3  0.2
# The 1st 3 samples of validation set
# ...
