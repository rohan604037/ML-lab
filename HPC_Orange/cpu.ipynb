# %% [markdown]
# <a href="https://colab.research.google.com/github/rohan604037/ML-lab/blob/main/HPC_Orange/cpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from numba import cuda
import math
import time
